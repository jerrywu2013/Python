# %%
for countdown in 5, 4, 3, 2, 1, "Hello World!":
    print(countdown)
# Out:
# 5
# 4
# 3
# 2
# 1
# Hello World!

# %%
News = [
    "Yahoo新聞",
    "蘋果新聞",
    "UDN新聞"
    ]
print(News[2])
# Out:
# UDN新聞

# %%
joke = {
    "學生": "老師我拉肚子了",
    "老師": "你就不能說的文雅點嗎?",
    "學生": "老師我菊部有降雨",
    "老師": "......",
    }
x = "學生"
print(x, "say:", joke[x])
# Out:
# 學生 say: 老師我菊部有降雨

# %%
import requests
url = "http://data.taipei/opendata/datalist/apiAccess?scope=resourceAquire&rid=540c0930-f25b-429c-9adf-128225dfe4f4"
response = requests.get(url)
data = response.json()
print(data)
# Out:
# {'result': {'limit': 10000, 'count': 1179, 'sort': '', 'offset': 0, 'results': [{'主類別': '職訓類', '課名': '檢測燃油壓力(104年度)-Y201515981', '課程資訊': 'http://elearning.taipei.gov.tw/co_courseDetail.php?detail_course_id=10062449', '時數': '1', '直接觀看': 'http://elearning.taipei.gov.tw/learn/index_view.php?cid=10062449', '副類別': '修護課程', '次類別': '汽機車修復', '_id': '1'}, {'主類別': '職訓類', '課名': '小籠湯包製作(104年度)-Y201515982', '課程資訊': 'http://elearning.taipei.gov.tw/co_courseDetail.php?detail_course_id=10062450', '時數': '1', '直接觀看': 'http://elearning.taipei.gov.tw/learn/index_view.php?cid=10062450', '副類別': '餐飲製作', '次類別': '中式餐飲', '_id': '2'}, {'主類別': '職訓類', '課名': '水電簡易維修(104年度)-Y201515996', '課程資訊': 'http://elearning.taipei.gov.tw/co_courseDetail.php?detail_course_id=10062609', '時數': '1', '直接觀看': 'http://elearning.taipei.gov.tw/learn/index_view.php?cid=10062609', '副類別': '修護課程', '次類別': '工作技能', '_id': '3'}, {'主類別': '職訓類', '課名': '尼斯沙拉(104年度)-Y201516000', '課程資訊': 'http://elearning.taipei.gov.tw/co_courseDetail.php?detail_course_id=10062671', '時數': '1', '直接觀看': 'http://elearning.taipei.gov.tw/learn/index_view.php?cid=10062671', '副類別': '餐飲製作', '次類別': '西式餐飲', '_id': '4'}, {'主類別': '職訓類', '課名': '商品攝影箱(104年度)-Y201516002', '課程資訊': 'http://elearning.taipei.gov.tw/co_courseDetail.php?detail_course_id=10062691', '時數': '1', '直接觀看': 'http://elearning.taipei.gov.tw/learn/index_view.php?cid=10062691', '副類別': '職場應用', '次類別': '攝影', '_id': '5'}, {'主類別': '職訓類', '課名': '基礎調酒(104年度)-Y201516004', '課程資訊': 'http://elearning.taipei.gov.tw/co_courseDetail.php?detail_course_id=10062711', '時數': '1', '直接觀看': 'http://elearning.taipei.gov.tw/learn/index_view.php?cid=10062711', '副類別': '餐飲製作', '次類別': '西式餐飲', '_id': '6'}, {'主類別': '職訓類', '課名': '發糕製作(104年度)-Y201516006', '課程資訊': 'http://elearning.taipei.gov.tw/co_courseDetail.php?detail_course_id=10062731', '時數': '1', '直接觀看': 'http://elearning.taipei.gov.tw/learn/index_view.php?cid=10062731', '副類別': '餐飲製作', '次類別': '中式餐飲', '_id': '7'}, {'主類別': '職訓類', '課名': '求職技巧(104年度)-Y201516008', '課程資訊': 'http://elearning.taipei.gov.tw/co_courseDetail.php?detail_course_id=10062769', '時數': '1', '直接觀看': 'http://elearning.taipei.gov.tw/learn/index_view.php?cid=10062769', '副類別': '職場應用', '次類別': '人資管理', '_id': '8'}, {'主類別': '職訓類', '課名': '津貼講解(104年度)-Y201516010', '課程資訊': 'http://elearning.taipei.gov.tw/co_courseDetail.php?detail_course_id=10062791', '時數': '1', '直接觀看': 'http://elearning.taipei.gov.tw/learn/index_view.php?cid=10062791', '副類別': '職場應用', '次類別': '人資管理', '_id': '9'}, {'主類別': '職訓類', '課名': '國際技能競賽(WorldSkills)(104年度)-Y201516012', '課程資訊': 'http://elearning.taipei.gov.tw/co_courseDetail.php?detail_course_id=10062811', '時數': '1', '直接觀看': 'http://elearning.taipei.gov.tw/learn/index_view.php?cid=10062811', '副類別': '職場應用', '次類別': '人資管理', '_id': '10'}, {'主類別': '職訓類', '課名': '裙子製作教學(104年度)-Y201516020', '課程資訊': 'http://elearning.taipei.gov.tw/co_courseDetail.php?detail_course_id=10063029', '時數': '2', '直接觀看': 'http://elearning.taipei.gov.tw/learn/index_view.php?cid=10063029', '副類別': '家政美容', '次類別': '手作縫紉', '_id': '11'}, {'主類別': '職訓類', '課名': '點銲鑽除(104年度)-Y201516021', '課程資訊': 'http://elearning.taipei.gov.tw/co_courseDetail.php?detail_course_id=10063049', '時數': '1', '直接觀看': 'http://elearning.taipei.gov.tw/learn/index_view.php?cid=10063049', '副類別': '修護課程', '次類別': '汽機車修復', '_id': '12'}, {'主類別': '職訓類', '課名': '輪胎檢查及調位(104年度)-Y201516022', '課程資訊': 'http://elearning.taipei.gov.tw/co_courseDetail.php?detail_course_id=10063069', '時數': '1', '直接觀看': 'http://elearning.taipei.gov.tw/learn/index_view.php?cid=10063069', '副類別': '修護課程', '次類別': '汽機車修復', '_id': '13'}, {'主類別': '職訓類', '課名': '自行車變速器調校(104年度)-Y201516023', '課程資訊': 'http://elearning.taipei.gov.tw/co_courseDetail.php?detail_course_id=10063089', '時數': '1', '直接觀看': 'http://elearning.taipei.gov.tw/learn/index_view.php?cid=10063089', '副類別': '修護課程', '次類別': '汽機車修復', '_id': '14'}, {'主類別': '職訓類', '課名': '機車起動馬達檢修(104年度)-Y201516025', '課程資訊': 'http://elearning.taipei.gov.tw/co_courseDetail.php?detail_course_id=10063091', '時數': '1', '直接觀看': 'http://elearn ...

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
8*9
# Out:
# 72

# %%
47
# Out:
# 47

# %%
print(47)
# Out:
# 47
